# %%
n = int((input('enter number ')))
a = 0
b = 1
print(str(a)+str(" ")+str(b) +str(" "),end="")
for i in range(n):
    c=a+b
    a=b
    b=c
    print(c,end=" ")
# Out:
# enter number5
# 0 1 1 2 3 5 8
